# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'E:\competition\COmsic Classifier IIT Roorkie\Cosmic-Classifier\data\thermoracleTrain.csv')
df = df.dropna(subset=['Prediction'])
df.sample(5)
# Out:
#        Atmospheric Density  Surface Temperature   Gravity  Water Content  \
# 2946             -0.359330                  NaN -1.505438      -1.001647
# 49717            -3.943396            -2.666076  0.940505       0.420699
# 40507             0.442552             2.642705  3.249037      -1.657455
# 9846              0.455629             1.733049 -4.071259      -0.381052
# 10079            -2.139734            -1.016604  2.299216      -1.787659
#
#        Mineral Abundance  Orbital Period  Proximity to Star  \
# 2946           -0.678929       -0.411427          -1.057516
# 49717          -1.189094        0.252388           0.570567
# 40507           1.129753             NaN           0.496335
# 9846            0.961152       -0.464685          -0.928507
# 10079           0.170803        1.283649          -0.696760
#
#       Magnetic Field Strength Radiation Levels  Atmospheric Composition Index  \
# 2946               Category_4       Category_8                       1.744636
# 49717              Category_8      Category_11                      -0.171510
# 40507              Category_7      Category_14                      -0.868353
# 9846              Category_10      Category_11                       1.492585
# 10079                     NaN      Category_10                       0.360138
#
#        Prediction
# 2946          5.0
# 49717         1.0
# 40507         9.0
# 9846          9.0
# 10079         8.0

# %%
df.isnull().sum()
# Out:
# Atmospheric Density              2842
# Surface Temperature              2896
# Gravity                          2826
# Water Content                    2936
# Mineral Abundance                2784
# Orbital Period                   2855
# Proximity to Star                2786
# Magnetic Field Strength          2941
# Radiation Levels                 2859
# Atmospheric Composition Index    2795
# Prediction                          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56961 entries, 0 to 59999
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Atmospheric Density            54119 non-null  float64
#  1   Surface Temperature            54065 non-null  float64
#  2   Gravity                        54135 non-null  float64
#  3   Water Content                  54025 non-null  float64
#  4   Mineral Abundance              54177 non-null  float64
#  5   Orbital Period                 54106 non-null  float64
#  6   Proximity to Star              54175 non-null  float64
#  7   Magnetic Field Strength        54020 non-null  object
#  8   Radiation Levels               54102 non-null  object
#  9   Atmospheric Composition Index  54166 non-null  float64
#  10  Prediction                     56961 non-null  float64
# dtypes: float64(9), object(2)
# memory usage: 5.2+ MB

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(df.drop(columns=['Prediction'], axis=1), df['Prediction'], test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (45568, 10)
# (11393, 10)
# (45568,)
# (11393,)

# %%
import math

columns =['Atmospheric Density',
'Gravity',
'Water Content',
'Mineral Abundance',
'Orbital Period',
'Proximity to Star',
'Atmospheric Composition Index',
'Prediction']

num_colss = 2  
num_rowss = math.ceil(len(columns) / num_colss)

fig, axes = plt.subplots(num_rowss, num_colss, figsize=(12, num_rowss * 4))
axes = axes.flatten()

for i, col in enumerate(columns):
    sns.boxplot(df[col],  color='blue', ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')


for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Impute values

# %%
columns = ['Atmospheric Density', 'Surface Temperature', 'Gravity',
           'Water Content', 'Mineral Abundance', 'Orbital Period',
           'Proximity to Star', 'Atmospheric Composition Index']

# %%
#imputing using median
from sklearn.impute import SimpleImputer
# si_median = SimpleImputer(strategy='median')

from sklearn.impute import KNNImputer
knn = KNNImputer()
x_train[columns] = knn.fit_transform(x_train[columns])
x_test[columns] = knn.transform(x_test[columns])


# df[columns] = si_median.fit_transform(df[columns])

# %%
freq_encode_cols = ['Radiation Levels' , 'Magnetic Field Strength']

for col in freq_encode_cols:
    freq_map = x_train[col].value_counts().to_dict()
    x_train[col] = x_train[col].map(freq_map)


si_mode = SimpleImputer(strategy='most_frequent')
x_train['Magnetic Field Strength'] = si_mode.fit_transform(x_train[['Magnetic Field Strength']])
x_train['Radiation Levels'] = si_mode.fit_transform(x_train[['Radiation Levels']])



freq_encode_cols = ['Radiation Levels' , 'Magnetic Field Strength']

for col in freq_encode_cols:
    freq_map = x_test[col].value_counts().to_dict()
    x_test[col] = x_test[col].map(freq_map)


si_mode = SimpleImputer(strategy='most_frequent')
x_test['Magnetic Field Strength'] = si_mode.fit_transform(x_test[['Magnetic Field Strength']])
x_test['Radiation Levels'] = si_mode.fit_transform(x_test[['Radiation Levels']])

# %%
x_train.isnull().sum()
# Out:
# Atmospheric Density              0
# Surface Temperature              0
# Gravity                          0
# Water Content                    0
# Mineral Abundance                0
# Orbital Period                   0
# Proximity to Star                0
# Magnetic Field Strength          0
# Radiation Levels                 0
# Atmospheric Composition Index    0
# dtype: int64

# %% [markdown]
# Remove outliars

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (45568, 10)
# (11393, 10)
# (45568,)
# (11393,)

# %% [markdown]
# Removing Skewness

# %%
from sklearn.preprocessing import PowerTransformer
columns = ['Atmospheric Density', 'Surface Temperature', 'Gravity',
           'Water Content', 'Mineral Abundance', 'Orbital Period',
           'Proximity to Star', 'Atmospheric Composition Index']

pt = PowerTransformer(method='yeo-johnson')
for col in columns:
    x_train[col] = pt.fit_transform(x_train[[col]])


pt = PowerTransformer(method='yeo-johnson')
for col in columns:
    x_test[col] = pt.fit_transform(x_test[[col]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

columns = ['Atmospheric Density', 'Surface Temperature', 'Gravity',
           'Water Content', 'Mineral Abundance', 'Orbital Period',
           'Proximity to Star', 'Atmospheric Composition Index']

num_colss = 2  
num_rowss = math.ceil(len(columns) / num_colss)

fig, axes = plt.subplots(num_rowss, num_colss, figsize=(12, num_rowss * 4))
axes = axes.flatten()

for i, col in enumerate(columns):
    sns.histplot(x_train[col], kde=True, color='blue', ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')


for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()

# Store original categorical columns
train_magnetic = x_train['Magnetic Field Strength'].copy()
train_radiation = x_train['Radiation Levels'].copy()
test_magnetic = x_test['Magnetic Field Strength'].copy()
test_radiation = x_test['Radiation Levels'].copy()

# Transform numerical columns
x_train_scaled = mms.fit_transform(x_train[columns])
x_test_scaled = mms.transform(x_test[columns])

# Convert back to DataFrame with proper indices
x_train = pd.DataFrame(x_train_scaled, columns=columns, index=train_magnetic.index)
x_test = pd.DataFrame(x_test_scaled, columns=columns, index=test_magnetic.index)

# Add back categorical columns
x_train['Magnetic Field Strength'] = train_magnetic
x_train['Radiation Levels'] = train_radiation
x_test['Magnetic Field Strength'] = test_magnetic
x_test['Radiation Levels'] = test_radiation

# Display results
print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
x_train.head()
# Out:
# Training data shape: (45568, 10)
# Test data shape: (11393, 10)
#        Atmospheric Density  Surface Temperature   Gravity  Water Content  \
# 43202             0.432370             0.835185  0.363699       0.437912
# 36025             0.345354             0.735400  0.611787       0.611897
# 29732             0.638509             0.525505  0.305496       0.453695
# 7995              0.440501             0.602484  0.617435       0.559629
# 34796             0.051050             0.403344  0.459614       0.567467
#
#        Mineral Abundance  Orbital Period  Proximity to Star  \
# 43202           0.291417        0.458272           0.731366
# 36025           0.442217        0.350421           0.514555
# 29732           0.123488        0.643020           0.480507
# 7995            0.405513        0.301295           0.491308
# 34796           0.295718        0.418230           0.605014
#
#        Atmospheric Composition Index  Magnetic Field Strength  \
# 43202                       0.536320                    952.0
# 36025                       0.289321                   4630.0
# 29732                       0.590101                    247.0
# 7995                        0.242000                   4630.0
# 34796                       0.414115                   6723.0
#
#        Radiation Levels
# 43202            6328.0
# 36025            3970.0
# 29732            6328.0
# 7995             1317.0
# 34796            6192.0

# %% [markdown]
# Encoding Categorical Features

# %%
freq_encode_cols = ['Radiation Levels' , 'Magnetic Field Strength']

for col in freq_encode_cols:
    freq_map = x_train[col].value_counts().to_dict()
    x_train[col] = x_train[col].map(freq_map)


si_mode = SimpleImputer(strategy='most_frequent')
x_train['Magnetic Field Strength'] = si_mode.fit_transform(x_train[['Magnetic Field Strength']])
x_train['Radiation Levels'] = si_mode.fit_transform(x_train[['Radiation Levels']])


for col in freq_encode_cols:
    freq_map = x_test[col].value_counts().to_dict()
    x_test[col] = x_test[col].map(freq_map)


si_mode = SimpleImputer(strategy='most_frequent')
x_test['Magnetic Field Strength'] = si_mode.fit_transform(x_test[['Magnetic Field Strength']])
x_test['Radiation Levels'] = si_mode.fit_transform(x_test[['Radiation Levels']])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

columns = ['Atmospheric Density', 'Surface Temperature', 'Gravity',
           'Water Content', 'Mineral Abundance', 'Orbital Period',
           'Proximity to Star', 'Atmospheric Composition Index', 'Magnetic Field Strength', 'Radiation Levels']

num_colss = 2  
num_rowss = math.ceil(len(columns) / num_colss)

fig, axes = plt.subplots(num_rowss, num_colss, figsize=(12, num_rowss * 4))
axes = axes.flatten()

for i, col in enumerate(columns):
    sns.histplot(x_train[col], kde=True, color='blue', ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')


for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
def remove_outliers_sync(x, y, cols):
    mask = pd.Series(True, index=x.index)
    for col in cols:
        Q1 = x[col].quantile(0.25)
        Q3 = x[col].quantile(0.75)
        IQR = Q3 - Q1
        lower, upper = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
        mask &= (x[col] >= lower) & (x[col] <= upper)
    return x[mask], y[mask]

# Remove outliers and keep x and y in sync for training and testing sets
x_train_clean, y_train_clean = remove_outliers_sync(x_train, y_train, columns)
x_test_clean,  y_test_clean  = remove_outliers_sync(x_test, y_test, columns)

# %%
x_train = x_train_clean
x_test = x_test_clean
y_train = y_train_clean
y_test = y_test_clean

# %%
print(x_train_clean.shape)
print(x_test_clean.shape)
print(y_train_clean.shape)
print(y_test_clean.shape)
# Out:
# (44309, 10)
# (11103, 10)
# (44309,)
# (11103,)

# %%
x_train['atmospheric pressure'] = x_train['Gravity']*x_train['Atmospheric Density']
x_train['Energy Recieved'] = x_train['Proximity to Star']*x_train['Orbital Period']
x_train['Water state'] = x_train['Water Content']*x_train['Surface Temperature']

x_test['atmospheric pressure'] = x_test['Gravity']*x_test['Atmospheric Density']
x_test['Energy Recieved'] = x_test['Proximity to Star']*x_test['Orbital Period']
x_test['Water state'] = x_test['Water Content']*x_test['Surface Temperature']

# %%
x_train['Thermal Efficiency'] = x_train['Surface Temperature']/x_train['Proximity to Star']
x_train['Atmospheric Retention'] = x_train['Atmospheric Density']/x_train['Gravity']
x_train['Water phase indicator'] = x_train['Water Content']/x_train['Surface Temperature']

x_test['Thermal Efficiency'] = x_test['Surface Temperature']/x_test['Proximity to Star']
x_test['Atmospheric Retention'] = x_test['Atmospheric Density']/x_test['Gravity']
x_test['Water phase indicator'] = x_test['Water Content']/x_test['Surface Temperature']

# %%
x_train['Surface Temperature Polynomial'] = x_train['Surface Temperature']**2
x_train['Gravity Polynomial'] = x_train['Gravity']**2
x_train['Proximity to Star Polynomial'] = x_train['Proximity to Star']**2

x_test['Surface Temperature Polynomial'] = x_test['Surface Temperature']**2
x_test['Gravity Polynomial'] = x_test['Gravity']**2
x_test['Proximity to Star Polynomial'] = x_test['Proximity to Star']**2

# %%
x_train['rf1'] = x_train['Water Content']/x_train['Mineral Abundance']
x_train['rf2'] = x_train['Atmospheric Density']/x_train['Surface Temperature']
x_train['rf3'] = x_train['Gravity']/x_train['Orbital Period']

x_test['rf1'] = x_test['Water Content']/x_test['Mineral Abundance']
x_test['rf2'] = x_test['Atmospheric Density']/x_test['Surface Temperature']
x_test['rf3'] = x_test['Gravity']/x_test['Orbital Period']

# %%
x_train.sample(5)
# Out:
#        Atmospheric Density  Surface Temperature   Gravity  Water Content  \
# 3940              0.190236             0.760496  0.409943       0.376209
# 19645             0.744608             0.497962  0.870205       0.305872
# 48946             0.188978             0.629365  0.443242       0.728159
# 34159             0.374244             0.533976  0.565075       0.292898
# 13309             0.580388             0.633702  0.739848       0.607175
#
#        Mineral Abundance  Orbital Period  Proximity to Star  \
# 3940            0.386470        0.571299           0.760490
# 19645           0.561739        0.341813           0.523635
# 48946           0.434989        0.505593           0.604673
# 34159           0.393649        0.232363           0.437118
# 13309           0.399066        0.388508           0.611426
#
#        Atmospheric Composition Index  Magnetic Field Strength  \
# 3940                        0.555702                     5959
# 19645                       0.473563                      952
# 48946                       0.478396                     6723
# 34159                       0.426023                     3454
# 13309                       0.529828                     6723
#
#        Radiation Levels  ...  Water state  Thermal Efficiency  \
# 3940               6192  ...     0.286105            1.000007
# 19645              2705  ...     0.152312            0.950972
# 48946              6192  ...     0.458278            1.040836
# 34159              7248  ...     0.156400            1.221583
# 13309              6192  ...     0.384768            1.036434
#
#        Atmospheric Retention  Water phase indicator  \
# 3940                0.464055               0.494689
# 19645               0.855670               0.614248
# 48946               0.426354               1.156973
# 34159               0.662291               0.548522
# 13309               0.784468               0.958139
#
#        Surface Temperature Polynomial  Gravity Polynomial  \
# 3940                         0.578354            0.168053
# 19645                        0.247966            0.757257
# 48946                        0.396101            0.196463
# 34159                        0.285130            0.319310
# 13309                        0.401578            0.547375
#
#        Proximity to Star Polynomial       rf1       rf2       rf3
# 3940                       0.578346  0.973449  0.250147  0.717562
# 19645                      0.274193  0.544508  1.495312  2.545848
# 48946                      0.365629  1.673968  0.300268  0.876678
# 34159                      0.191072  0.744058  0.700863  2.431866
# 13309                      0.373841  1.521490  0.915868  1.904332
#
# [5 rows x 22 columns]

# %%
mask_train = np.isfinite(x_train).all(axis=1)
x_train = x_train[mask_train].reset_index(drop=True)
y_train = y_train[mask_train].reset_index(drop=True)

# For the testing set
mask_test = np.isfinite(x_test).all(axis=1)
x_test = x_test[mask_test].reset_index(drop=True)
y_test = y_test[mask_test].reset_index(drop=True)

# %% [markdown]
# xgboost

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score , recall_score , f1_score
from sklearn.model_selection import cross_val_score
from bayes_opt import BayesianOptimization
import xgboost as xgb

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (44309, 22)
# (44309,)

# %%
y_train.sample(10)
# Out:
# 26135    2.0
# 18729    9.0
# 28452    5.0
# 28482    0.0
# 13047    5.0
# 36915    1.0
# 26413    0.0
# 27083    3.0
# 41627    1.0
# 35686    0.0
# Name: Prediction, dtype: float64

# %%
def xgb_csv(max_depth, learning_rate, n_estimators, gamma, min_child_weight, subsample, colsample_bytree):
    params = {
        'max_depth': int(max_depth),
        'learning_rate': learning_rate,
        'n_estimators': int(n_estimators),
        'gamma': gamma,
        'min_child_weight': min_child_weight,
        'subsample': subsample,
        'colsample_bytree': colsample_bytree,
        'objective': 'multi:softmax', 
        'num_class': 10,  
        'eval_metric': ['mlogloss', 'merror'] 
    }

    cv_results = cross_val_score(
        xgb.XGBClassifier(**params),
        x_train, y_train,
        scoring='accuracy',
        cv=5
    )

    return cv_results.mean()

# %%
pbounds = {
    'max_depth': (3, 12),        
    'learning_rate': (0.01, 0.1), 
    'n_estimators': (100, 1000),  
    'gamma': (0, 5),              
    'min_child_weight': (1, 10),  
    'subsample': (0.6, 1),        
    'colsample_bytree': (0.6, 1)  
}

optimizer = BayesianOptimization(
    f=xgb_csv,
    pbounds=pbounds,
    random_state=42,
    verbose=2  
)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (44309, 22)
# (11103, 22)
# (44309,)
# (11103,)

# %%
import numpy as np

# Check for infinite values
print(np.isinf(x_train).sum())

# Check for very large values
print(np.max(x_train))
# Out:
# Atmospheric Density               0
# Surface Temperature               0
# Gravity                           0
# Water Content                     0
# Mineral Abundance                 0
# Orbital Period                    0
# Proximity to Star                 0
# Atmospheric Composition Index     0
# Magnetic Field Strength           0
# Radiation Levels                  0
# atmospheric pressure              0
# Energy Recieved                   0
# Water state                       0
# Thermal Efficiency                0
# Atmospheric Retention             0
# Water phase indicator             0
# Surface Temperature Polynomial    0
# Gravity Polynomial                0
# Proximity to Star Polynomial      0
# rf1                               0
# rf2                               0
# rf3                               0
# dtype: int64
# 9672.0

# %%
optimizer.maximize(
    init_points = 10,
    n_iter = 15
)

print(optimizer.max)
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | min_ch...
# | 24        | 0.8677    | 0.6066    | 0.2905    | 0.01442   | 9.401     | 5.7       | 365.9     | 0.7044    |
# | 25        | 0.8841    | 0.8132    | 0.4217    | 0.0826    | 9.775     | 8.99      | 365.0     | 0.6449    |
# =============================================================================================================
# {'target': np.float64(0.8859599286260982), 'params': {'colsample_bytree': np.float64(0.6786078121721622), 'gamma': np.float64(0.11991037254682146), 'learning_rate': np.float64(0.0812716491083964), 'max_depth': np.float64(10.608596766513095), 'min_child_weight': np.float64(7.461081373768515), 'n_estimators': np.float64(365.8535966918183), 'subsample': np.float64(0.8162991052130569)}}

# %%
from sklearn.metrics import accuracy_score , classification_report

# %%
model = xgb.XGBClassifier(
        max_depth=int(10.608596766513095),
        learning_rate=0.0812716491083964,
        n_estimators=int(365.8535966918183),
        gamma=0.11991037254682146,
        min_child_weight=7.461081373768515,
        subsample=0.8162991052130569,
        colsample_bytree=0.6786078121721622,
        objective='multi:softmax', 
        num_class=10,  
        eval_metric=['mlogloss',  'merror']
)

model.fit(x_train , y_train)
y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test , y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8033

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.93      0.90      1042
#          1.0       0.97      0.97      0.97      1311
#          2.0       0.82      0.84      0.83      1084
#          3.0       0.60      0.85      0.70      1150
#          4.0       0.74      0.86      0.80      1085
#          5.0       0.76      0.73      0.74      1014
#          6.0       0.91      0.90      0.91      1052
#          7.0       0.80      0.93      0.86      1173
#          8.0       0.77      0.42      0.55      1076
#          9.0       0.86      0.56      0.68      1116
#
#     accuracy                           0.80     11103
#    macro avg       0.81      0.80      0.79     11103
# weighted avg       0.81      0.80      0.80     11103

# %%
import xgboost as xgb
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_openml



# Define evaluation set
eval_set = [(x_train, y_train), (x_test, y_test)]

# Train the model
modelxgb = xgb.XGBClassifier(
    n_estimators=500,  # Increase the number of boosting rounds
    eval_metric=['merror', 'mlogloss'],
    use_label_encoder=False,
    objective='multi:softmax',
    num_class=10,
    tree_method='gpu_hist'  # Enable GPU acceleration
)

modelxgb.fit(
    x_train, 
    y_train,
    eval_set=eval_set,
    verbose=True
)

# Retrieve evaluation results
results = modelxgb.evals_result()
epochs = len(results['validation_0']['merror'])  # Changed 'error' to 'merror'
x_axis = range(epochs)

# Plot training and test error
plt.figure(figsize=(10, 5))
plt.plot(x_axis, results['validation_0']['merror'], label='Train Error')
plt.plot(x_axis, results['validation_1']['merror'], label='Test Error')
plt.plot(x_axis, results['validation_0']['mlogloss'], label='logloss')
plt.xlabel('Epoch')
plt.ylabel('Multi-class Error Rate')
plt.title('XGBoost: Training vs Test Error')
plt.legend()
plt.show()
# Out:
# C:\Users\Shiva\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py:158: UserWarning: [20:07:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\Shiva\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py:158: UserWarning: [20:07:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-merror:0.20966	validation_0-mlogloss:1.48992	validation_1-merror:0.25741	validation_1-mlogloss:1.52847
# [1]	validation_0-merror:0.18937	validation_0-mlogloss:1.20591	validation_1-merror:0.23696	validation_1-mlogloss:1.27253
# [2]	validation_0-merror:0.17899	validation_0-mlogloss:1.02297	validation_1-merror:0.23075	validation_1-mlogloss:1.11617
# [3]	validation_0-merror:0.17123	validation_0-mlogloss:0.89020	validation_1-merror:0.22444	validation_1-mlogloss:1.00366
# [4]	validation_0-merror:0.16340	validation_0-mlogloss:0.78955	validation_1-merror:0.21652	validation_1-mlogloss:0.91783
# [5]	validation_0-merror:0.15581	validation_0-mlogloss:0.71065	validation_1-merror:0.21265	validation_1-mlogloss:0.85477
# [6]	validation_0-merror:0.15110	validation_0-mlogloss:0.64736	validation_1-merror:0.21102	validation_1-mlogloss:0.80722
# [7]	validation_0-merror:0.14676	validation_0-mlogloss:0.59746	validation_1-merror:0.20850	validation_1-mlogloss:0.76605
# [8]	validation_0-merror:0.14060	validation_0-mlogloss:0.55469	validation_1-merror:0.20787	validation_1-mlogloss:0.73790
# [9]	validation_0-merror:0.13528	validation_0-mlogloss:0.52022	validation_1-merror:0.20724	validation_1-mlogloss:0.71213
# [10]	validation_0-merror:0.13058	validation_0-mlogloss:0.48943	validation_1-merror:0.20319	validation_1-mlogloss:0.69206
# [11]	validation_0-merror:0.12614	validation_0-mlogloss:0.46278	validation_1-merror:0.20409	validation_1-mlogloss:0.67955
# [12]	validation_0-merror:0.12221	validation_0-mlogloss:0.44041	validation_1-merror:0.20184	validation_1-mlogloss:0.65973
# [13]	validation_0-merror:0.11889	validation_0-mlogloss:0.42096	validation_1-merror:0.20067	validation_1-mlogloss:0.64957
# [14]	validation_0-merror:0.11668	validation_0-mlogloss:0.40551	validation_1-merror:0.20130	validation_1-mlogloss:0.64240
# [15]	validation_0-merror:0.11341	validation_0-mlogloss:0.39008	validation_1-merror:0.20184	validation_1-mlogloss:0.63170
# [16]	validation_0-merror:0.11131	validation_0-mlogloss:0.37825	validation_1-merror:0.20301	validation_1-mlogloss:0.62797
# [17]	validation_0-merror:0.10896	validation_0-mlogloss:0.36732	validation_1-merror:0.20535	validation_1-mlogloss:0.62348
# [18]	validation_0-merror:0.10639	validation_0-mlogloss:0.35790	validation_1-merror:0.20571	validation_1-mlogloss:0.62164
# [19]	validation_0-merror:0.10461	validation_0-mlogloss:0.34748	validation_1-merror:0.20859	validation_1-mlogloss:0.62288
# [20]	validation_0-merror:0.10190	validation_0-mlogloss:0.33711	validation_1-merror:0.20805	validation_1-mlogloss:0.61788
# [21]	validation_0-merror:0.10025	validation_0-mlogloss:0.32935	validation_1-merror:0.20850	validation_1-mlogloss:0.61537
# [22]	validation_0-merror:0.09829	validation_0-mlogloss:0.32167	validation_1-merror:0.20985	validation_1-mlogloss:0.61623
# [23]	validation_0-merror:0.09666	validation_0-mlogloss:0.31426	validation_1-merror:0.21030	validation_1-mlogloss:0.61136
# [24]	validation_0-merror:0.09501	validation_0-mlogloss:0.30759	validation_1-merror:0.20886	validation_1-mlogloss:0.60413
# [49]	validation_0-merror:0.05845	validation_0-mlogloss:0.20280	validation_1-merror:0.21274	validation_1-mlogloss:0.61162
# [50]	validation_0-merror:0.05685	validation_0-mlogloss:0.19987	validation_1-merror:0.21328	validation_1-mlogloss:0.61057
# [51]	validation_0-merror:0.05599	validation_0-mlogloss:0.19750	validation_1-merror:0.21292	validation_1-mlogloss:0.61074
# [52]	validation_0-merror:0.05491	validation_0-mlogloss:0.19464	validation_1-merror:0.21310	validation_1-mlogloss:0.61197
# [53]	validation_0-merror:0.05378	validation_0-mlogloss:0.19160	validation_1-merror:0.21265	validation_1-mlogloss:0.61459
# [54]	validation_0-merror:0.05279	validation_0-mlogloss:0.18911	validation_1-merror:0.21463	validation_1-mlogloss:0.61851
# [55]	validation_0-merror:0.05191	validation_0-mlogloss:0.18643	validation_1-merror:0.21337	validation_1-mlogloss:0.62022
# [56]	validation_0-merror:0.05098	validation_0-mlogloss:0.18419	validation_1-merror:0.21247	validation_1-mlogloss:0.61802
# [57]	validation_0-merror:0.04999	validation_0-mlogloss:0.18120	validation_1-merror:0.21256	validation_1-mlogloss:0.61846
# [58]	validation_0-merror:0.04909	validation_0-mlogloss:0.17878	validation_1-merror:0.21490	validation_1-mlogloss:0.62152
# [59]	validation_0-merror:0.04816	validation_0-mlogloss:0.17578	validation_1-merror:0.21472	validation_1-mlogloss:0.62137
# [60]	validation_0-merror:0.04746	validation_0-mlogloss:0.17365	validation_1-merror:0.21373	validation_1-mlogloss:0.62164
# [61]	validation_0-merror:0.04604	validation_0-mlogloss:0.17031	validation_1-merror:0.21463	validation_1-mlogloss:0.62346
# [62]	validation_0-merror:0.04536	validation_0-mlogloss:0.16804	validation_1-merror:0.21427	validation_1-mlogloss:0.62470
# [63]	validation_0-merror:0.04466	validation_0-mlogloss:0.16605	validation_1-merror:0.21382	validation_1-mlogloss:0.62301
# [64]	validation_0-merror:0.04358	validation_0-mlogloss:0.16391	validation_1-merror:0.21454	validation_1-mlogloss:0.62348
# [65]	validation_0-merror:0.04234	validation_0-mlogloss:0.16119	validation_1-merror:0.21400	validation_1-mlogloss:0.62262
# [66]	validation_0-merror:0.04130	validation_0-mlogloss:0.15888	validation_1-merror:0.21418	validation_1-mlogloss:0.62228
# [67]	validation_0-merror:0.04031	validation_0-mlogloss:0.15686	validation_1-merror:0.21409	validation_1-mlogloss:0.62367
# [68]	validation_0-merror:0.03943	validation_0-mlogloss:0.15492	validation_1-merror:0.21418	validation_1-mlogloss:0.62284
# [69]	validation_0-merror:0.03877	validation_0-mlogloss:0.15279	validation_1-merror:0.21292	validation_1-mlogloss:0.62213
# [70]	validation_0-merror:0.03794	validation_0-mlogloss:0.15100	validation_1-merror:0.21265	validation_1-mlogloss:0.62144
# [71]	validation_0-merror:0.03742	validation_0-mlogloss:0.14968	validation_1-merror:0.21265	validation_1-mlogloss:0.62169
# [72]	validation_0-merror:0.03688	validation_0-mlogloss:0.14761	validation_1-merror:0.21228	validation_1-mlogloss:0.62047
# [73]	validation_0-merror:0.03618	validation_0-mlogloss:0.14561	validation_1-merror:0.21219	validation_1-mlogloss:0.62070
# [74]	validation_0-merror:0.03555	validation_0-mlogloss:0.14395	validation_1-merror:0.21247	validation_1-mlogloss:0.62164
# [75]	validation_0-merror:0.03494	validation_0-mlogloss:0.14242	validation_1-merror:0.21192	validation_1-mlogloss:0.62120
# [76]	validation_0-merror:0.03424	validation_0-mlogloss:0.14052	validation_1-merror:0.21301	validation_1-mlogloss:0.62201
# [77]	validation_0-merror:0.03388	validation_0-mlogloss:0.13882	validation_1-merror:0.21355	validation_1-mlogloss:0.62478
# [78]	validation_0-merror:0.03318	validation_0-mlogloss:0.13718	validation_1-merror:0.21436	validation_1-mlogloss:0.62592
# [79]	validation_0-merror:0.03248	validation_0-mlogloss:0.13544	validation_1-merror:0.21445	validation_1-mlogloss:0.62547
# [80]	validation_0-merror:0.03196	validation_0-mlogloss:0.13387	validation_1-merror:0.21373	validation_1-mlogloss:0.62576
# [81]	validation_0-merror:0.03054	validation_0-mlogloss:0.13143	validation_1-merror:0.21517	validation_1-mlogloss:0.62629
# [82]	validation_0-merror:0.02999	validation_0-mlogloss:0.12964	validation_1-merror:0.21490	validation_1-mlogloss:0.62796
# [83]	validation_0-merror:0.02968	validation_0-mlogloss:0.12818	validation_1-merror:0.21499	validation_1-mlogloss:0.62772
# [84]	validation_0-merror:0.02896	validation_0-mlogloss:0.12665	validation_1-merror:0.21535	validation_1-mlogloss:0.62706
# [85]	validation_0-merror:0.02817	validation_0-mlogloss:0.12474	validation_1-merror:0.21544	validation_1-mlogloss:0.62688
# [86]	validation_0-merror:0.02729	validation_0-mlogloss:0.12273	validation_1-merror:0.21508	validation_1-mlogloss:0.62779
# [87]	validation_0-merror:0.02683	validation_0-mlogloss:0.12096	validation_1-merror:0.21517	validation_1-mlogloss:0.62677
# [88]	validation_0-merror:0.02634	validation_0-mlogloss:0.11924	validation_1-merror:0.21508	validation_1-mlogloss:0.62657
# [89]	validation_0-merror:0.02591	validation_0-mlogloss:0.11787	validation_1-merror:0.21409	validation_1-mlogloss:0.62637
# [90]	validation_0-merror:0.02507	validation_0-mlogloss:0.11624	validation_1-merror:0.21481	validation_1-mlogloss:0.62751
# [91]	validation_0-merror:0.02437	validation_0-mlogloss:0.11464	validation_1-merror:0.21436	validation_1-mlogloss:0.62775
# [92]	validation_0-merror:0.02395	validation_0-mlogloss:0.11331	validation_1-merror:0.21589	validation_1-mlogloss:0.63156
# [93]	validation_0-merror:0.02318	validation_0-mlogloss:0.11175	validation_1-merror:0.21544	validation_1-mlogloss:0.63139
# [94]	validation_0-merror:0.02273	validation_0-mlogloss:0.11003	validation_1-merror:0.21571	validation_1-mlogloss:0.63243
# [95]	validation_0-merror:0.02209	validation_0-mlogloss:0.10856	validation_1-merror:0.21589	validation_1-mlogloss:0.63565
# [96]	validation_0-merror:0.02153	validation_0-mlogloss:0.10706	validation_1-merror:0.21517	validation_1-mlogloss:0.63497
# [97]	validation_0-merror:0.02130	validation_0-mlogloss:0.10564	validation_1-merror:0.21688	validation_1-mlogloss:0.63875
# [98]	validation_0-merror:0.02074	validation_0-mlogloss:0.10393	validation_1-merror:0.21634	validation_1-mlogloss:0.63831
# [99]	validation_0-merror:0.02011	validation_0-mlogloss:0.10221	validation_1-merror:0.21634	validation_1-mlogloss:0.63769
# [100]	validation_0-merror:0.01945	validation_0-mlogloss:0.10070	validation_1-merror:0.21670	validation_1-mlogloss:0.63898
# [101]	validation_0-merror:0.01905	validation_0-mlogloss:0.09975	validation_1-merror:0.21670	validation_1-mlogloss:0.64115
# [102]	validation_0-merror:0.01875	validation_0-mlogloss:0.09845	validation_1-merror:0.21877	validation_1-mlogloss:0.64589
# [103]	validation_0-merror:0.01828	validation_0-mlogloss:0.09727	validation_1-merror:0.21823	validation_1-mlogloss:0.64660
# [104]	validation_0-merror:0.01792	validation_0-mlogloss:0.09642	validation_1-merror:0.21832	validation_1-mlogloss:0.64872
# [105]	validation_0-merror:0.01720	validation_0-mlogloss:0.09501	validation_1-merror:0.21850	validation_1-mlogloss:0.64919
# [106]	validation_0-merror:0.01681	validation_0-mlogloss:0.09351	validation_1-merror:0.21895	validation_1-mlogloss:0.65047
# [107]	validation_0-merror:0.01602	validation_0-mlogloss:0.09205	validation_1-merror:0.21886	validation_1-mlogloss:0.64985
# [108]	validation_0-merror:0.01546	validation_0-mlogloss:0.09087	validation_1-merror:0.21904	validation_1-mlogloss:0.64981
# [109]	validation_0-merror:0.01478	validation_0-mlogloss:0.08924	validation_1-merror:0.21832	validation_1-mlogloss:0.64924
# [110]	validation_0-merror:0.01456	validation_0-mlogloss:0.08823	validation_1-merror:0.21877	validation_1-mlogloss:0.65005
# [111]	validation_0-merror:0.01402	validation_0-mlogloss:0.08690	validation_1-merror:0.21823	validation_1-mlogloss:0.64827
# [112]	validation_0-merror:0.01345	validation_0-mlogloss:0.08543	validation_1-merror:0.21796	validation_1-mlogloss:0.64799
# [113]	validation_0-merror:0.01293	validation_0-mlogloss:0.08439	validation_1-merror:0.21769	validation_1-mlogloss:0.64810
# [114]	validation_0-merror:0.01250	validation_0-mlogloss:0.08329	validation_1-merror:0.21769	validation_1-mlogloss:0.64985
# [115]	validation_0-merror:0.01223	validation_0-mlogloss:0.08229	validation_1-merror:0.21679	validation_1-mlogloss:0.65048
# [116]	validation_0-merror:0.01171	validation_0-mlogloss:0.08127	validation_1-merror:0.21742	validation_1-mlogloss:0.65251
# [117]	validation_0-merror:0.01133	validation_0-mlogloss:0.08014	validation_1-merror:0.21805	validation_1-mlogloss:0.65309
# [118]	validation_0-merror:0.01095	validation_0-mlogloss:0.07876	validation_1-merror:0.21778	validation_1-mlogloss:0.65205
# [119]	validation_0-merror:0.01079	validation_0-mlogloss:0.07808	validation_1-merror:0.21823	validation_1-mlogloss:0.65430
# [120]	validation_0-merror:0.01052	validation_0-mlogloss:0.07707	validation_1-merror:0.21760	validation_1-mlogloss:0.65361
# [145]	validation_0-merror:0.00390	validation_0-mlogloss:0.05543	validation_1-merror:0.21562	validation_1-mlogloss:0.66827
# [146]	validation_0-merror:0.00372	validation_0-mlogloss:0.05457	validation_1-merror:0.21634	validation_1-mlogloss:0.66953
# [147]	validation_0-merror:0.00375	validation_0-mlogloss:0.05382	validation_1-merror:0.21616	validation_1-mlogloss:0.67015
# [148]	validation_0-merror:0.00359	validation_0-mlogloss:0.05310	validation_1-merror:0.21580	validation_1-mlogloss:0.67076
# [149]	validation_0-merror:0.00339	validation_0-mlogloss:0.05237	validation_1-merror:0.21517	validation_1-mlogloss:0.67129
# [150]	validation_0-merror:0.00311	validation_0-mlogloss:0.05173	validation_1-merror:0.21499	validation_1-mlogloss:0.67115
# [151]	validation_0-merror:0.00305	validation_0-mlogloss:0.05115	validation_1-merror:0.21517	validation_1-mlogloss:0.67338
# [152]	validation_0-merror:0.00289	validation_0-mlogloss:0.05058	validation_1-merror:0.21454	validation_1-mlogloss:0.67329
# [153]	validation_0-merror:0.00282	validation_0-mlogloss:0.05010	validation_1-merror:0.21463	validation_1-mlogloss:0.67331
# [154]	validation_0-merror:0.00271	validation_0-mlogloss:0.04938	validation_1-merror:0.21490	validation_1-mlogloss:0.67396
# [155]	validation_0-merror:0.00253	validation_0-mlogloss:0.04857	validation_1-merror:0.21463	validation_1-mlogloss:0.67382
# [156]	validation_0-merror:0.00246	validation_0-mlogloss:0.04800	validation_1-merror:0.21490	validation_1-mlogloss:0.67728
# [157]	validation_0-merror:0.00248	validation_0-mlogloss:0.04726	validation_1-merror:0.21481	validation_1-mlogloss:0.67742
# [158]	validation_0-merror:0.00237	validation_0-mlogloss:0.04653	validation_1-merror:0.21463	validation_1-mlogloss:0.68017
# [159]	validation_0-merror:0.00219	validation_0-mlogloss:0.04596	validation_1-merror:0.21553	validation_1-mlogloss:0.68070
# [160]	validation_0-merror:0.00205	validation_0-mlogloss:0.04539	validation_1-merror:0.21517	validation_1-mlogloss:0.68194
# [161]	validation_0-merror:0.00192	validation_0-mlogloss:0.04499	validation_1-merror:0.21490	validation_1-mlogloss:0.68228
# [162]	validation_0-merror:0.00183	validation_0-mlogloss:0.04425	validation_1-merror:0.21544	validation_1-mlogloss:0.68249
# [163]	validation_0-merror:0.00172	validation_0-mlogloss:0.04377	validation_1-merror:0.21526	validation_1-mlogloss:0.68236
# [164]	validation_0-merror:0.00165	validation_0-mlogloss:0.04311	validation_1-merror:0.21472	validation_1-mlogloss:0.68212
# [165]	validation_0-merror:0.00151	validation_0-mlogloss:0.04240	validation_1-merror:0.21499	validation_1-mlogloss:0.68281
# [166]	validation_0-merror:0.00147	validation_0-mlogloss:0.04170	validation_1-merror:0.21490	validation_1-mlogloss:0.68232
# [167]	validation_0-merror:0.00147	validation_0-mlogloss:0.04107	validation_1-merror:0.21544	validation_1-mlogloss:0.68407
# [168]	validation_0-merror:0.00131	validation_0-mlogloss:0.04062	validation_1-merror:0.21508	validation_1-mlogloss:0.68383
# [169]	validation_0-merror:0.00122	validation_0-mlogloss:0.04005	validation_1-merror:0.21508	validation_1-mlogloss:0.68370
# [218]	validation_0-merror:0.00011	validation_0-mlogloss:0.02304	validation_1-merror:0.21706	validation_1-mlogloss:0.72249
# [219]	validation_0-merror:0.00011	validation_0-mlogloss:0.02283	validation_1-merror:0.21697	validation_1-mlogloss:0.72331
# [220]	validation_0-merror:0.00011	validation_0-mlogloss:0.02268	validation_1-merror:0.21688	validation_1-mlogloss:0.72413
# [221]	validation_0-merror:0.00011	validation_0-mlogloss:0.02248	validation_1-merror:0.21634	validation_1-mlogloss:0.72465
# [222]	validation_0-merror:0.00011	validation_0-mlogloss:0.02228	validation_1-merror:0.21679	validation_1-mlogloss:0.72486
# [223]	validation_0-merror:0.00009	validation_0-mlogloss:0.02207	validation_1-merror:0.21643	validation_1-mlogloss:0.72596
# [224]	validation_0-merror:0.00009	validation_0-mlogloss:0.02182	validation_1-merror:0.21652	validation_1-mlogloss:0.72802
# [225]	validation_0-merror:0.00007	validation_0-mlogloss:0.02157	validation_1-merror:0.21661	validation_1-mlogloss:0.72766
# [226]	validation_0-merror:0.00005	validation_0-mlogloss:0.02134	validation_1-merror:0.21607	validation_1-mlogloss:0.72837
# [227]	validation_0-merror:0.00005	validation_0-mlogloss:0.02106	validation_1-merror:0.21607	validation_1-mlogloss:0.72880
# [228]	validation_0-merror:0.00005	validation_0-mlogloss:0.02085	validation_1-merror:0.21589	validation_1-mlogloss:0.72981
# [229]	validation_0-merror:0.00005	validation_0-mlogloss:0.02067	validation_1-merror:0.21553	validation_1-mlogloss:0.73037
# [230]	validation_0-merror:0.00002	validation_0-mlogloss:0.02051	validation_1-merror:0.21589	validation_1-mlogloss:0.73036
# [231]	validation_0-merror:0.00002	validation_0-mlogloss:0.02032	validation_1-merror:0.21580	validation_1-mlogloss:0.73155
# [232]	validation_0-merror:0.00002	validation_0-mlogloss:0.02013	validation_1-merror:0.21625	validation_1-mlogloss:0.73321
# [233]	validation_0-merror:0.00005	validation_0-mlogloss:0.01995	validation_1-merror:0.21562	validation_1-mlogloss:0.73384
# [234]	validation_0-merror:0.00005	validation_0-mlogloss:0.01979	validation_1-merror:0.21598	validation_1-mlogloss:0.73377
# [235]	validation_0-merror:0.00005	validation_0-mlogloss:0.01955	validation_1-merror:0.21571	validation_1-mlogloss:0.73337
# [236]	validation_0-merror:0.00005	validation_0-mlogloss:0.01936	validation_1-merror:0.21544	validation_1-mlogloss:0.73378
# [237]	validation_0-merror:0.00002	validation_0-mlogloss:0.01907	validation_1-merror:0.21499	validation_1-mlogloss:0.73388
# [238]	validation_0-merror:0.00002	validation_0-mlogloss:0.01887	validation_1-merror:0.21526	validation_1-mlogloss:0.73423
# [239]	validation_0-merror:0.00002	validation_0-mlogloss:0.01869	validation_1-merror:0.21481	validation_1-mlogloss:0.73383
# [240]	validation_0-merror:0.00002	validation_0-mlogloss:0.01851	validation_1-merror:0.21562	validation_1-mlogloss:0.73604
# [241]	validation_0-merror:0.00002	validation_0-mlogloss:0.01831	validation_1-merror:0.21508	validation_1-mlogloss:0.73634
# [242]	validation_0-merror:0.00002	validation_0-mlogloss:0.01811	validation_1-merror:0.21526	validation_1-mlogloss:0.73683
# [243]	validation_0-merror:0.00002	validation_0-mlogloss:0.01796	validation_1-merror:0.21517	validation_1-mlogloss:0.73717
# [244]	validation_0-merror:0.00000	validation_0-mlogloss:0.01779	validation_1-merror:0.21526	validation_1-mlogloss:0.73732
# [245]	validation_0-merror:0.00000	validation_0-mlogloss:0.01757	validation_1-merror:0.21535	validation_1-mlogloss:0.73758
# [246]	validation_0-merror:0.00000	validation_0-mlogloss:0.01736	validation_1-merror:0.21562	validation_1-mlogloss:0.73880
# [247]	validation_0-merror:0.00000	validation_0-mlogloss:0.01719	validation_1-merror:0.21481	validation_1-mlogloss:0.73883
# [248]	validation_0-merror:0.00000	validation_0-mlogloss:0.01703	validation_1-merror:0.21490	validation_1-mlogloss:0.73856
# [249]	validation_0-merror:0.00000	validation_0-mlogloss:0.01687	validation_1-merror:0.21562	validation_1-mlogloss:0.73899
# [250]	validation_0-merror:0.00000	validation_0-mlogloss:0.01673	validation_1-merror:0.21517	validation_1-mlogloss:0.73919
# [251]	validation_0-merror:0.00000	validation_0-mlogloss:0.01654	validation_1-merror:0.21544	validation_1-mlogloss:0.73933
# [252]	validation_0-merror:0.00000	validation_0-mlogloss:0.01633	validation_1-merror:0.21580	validation_1-mlogloss:0.74011
# [253]	validation_0-merror:0.00000	validation_0-mlogloss:0.01616	validation_1-merror:0.21616	validation_1-mlogloss:0.74165
# [254]	validation_0-merror:0.00000	validation_0-mlogloss:0.01600	validation_1-merror:0.21562	validation_1-mlogloss:0.74285
# [255]	validation_0-merror:0.00000	validation_0-mlogloss:0.01585	validation_1-merror:0.21634	validation_1-mlogloss:0.74356
# [256]	validation_0-merror:0.00000	validation_0-mlogloss:0.01570	validation_1-merror:0.21580	validation_1-mlogloss:0.74394
# [257]	validation_0-merror:0.00000	validation_0-mlogloss:0.01557	validation_1-merror:0.21625	validation_1-mlogloss:0.74449
# [258]	validation_0-merror:0.00000	validation_0-mlogloss:0.01546	validation_1-merror:0.21598	validation_1-mlogloss:0.74458
# [259]	validation_0-merror:0.00000	validation_0-mlogloss:0.01536	validation_1-merror:0.21598	validation_1-mlogloss:0.74459
# [260]	validation_0-merror:0.00000	validation_0-mlogloss:0.01522	validation_1-merror:0.21625	validation_1-mlogloss:0.74528
# [261]	validation_0-merror:0.00000	validation_0-mlogloss:0.01506	validation_1-merror:0.21580	validation_1-mlogloss:0.74725
# [262]	validation_0-merror:0.00000	validation_0-mlogloss:0.01494	validation_1-merror:0.21706	validation_1-mlogloss:0.75322
# [263]	validation_0-merror:0.00000	validation_0-mlogloss:0.01481	validation_1-merror:0.21652	validation_1-mlogloss:0.75418
# [264]	validation_0-merror:0.00000	validation_0-mlogloss:0.01465	validation_1-merror:0.21634	validation_1-mlogloss:0.75348
# [265]	validation_0-merror:0.00000	validation_0-mlogloss:0.01452	validation_1-merror:0.21679	validation_1-mlogloss:0.75784
# [290]	validation_0-merror:0.00000	validation_0-mlogloss:0.01181	validation_1-merror:0.21814	validation_1-mlogloss:0.77346
# [291]	validation_0-merror:0.00000	validation_0-mlogloss:0.01169	validation_1-merror:0.21841	validation_1-mlogloss:0.77426
# [292]	validation_0-merror:0.00000	validation_0-mlogloss:0.01161	validation_1-merror:0.21796	validation_1-mlogloss:0.77454
# [293]	validation_0-merror:0.00000	validation_0-mlogloss:0.01151	validation_1-merror:0.21742	validation_1-mlogloss:0.77522
# [294]	validation_0-merror:0.00000	validation_0-mlogloss:0.01143	validation_1-merror:0.21787	validation_1-mlogloss:0.77793
# [295]	validation_0-merror:0.00000	validation_0-mlogloss:0.01136	validation_1-merror:0.21760	validation_1-mlogloss:0.77835
# [296]	validation_0-merror:0.00000	validation_0-mlogloss:0.01127	validation_1-merror:0.21751	validation_1-mlogloss:0.77836
# [297]	validation_0-merror:0.00000	validation_0-mlogloss:0.01119	validation_1-merror:0.21733	validation_1-mlogloss:0.77953
# [298]	validation_0-merror:0.00000	validation_0-mlogloss:0.01113	validation_1-merror:0.21760	validation_1-mlogloss:0.77931
# [299]	validation_0-merror:0.00000	validation_0-mlogloss:0.01104	validation_1-merror:0.21760	validation_1-mlogloss:0.78027
# [300]	validation_0-merror:0.00000	validation_0-mlogloss:0.01097	validation_1-merror:0.21760	validation_1-mlogloss:0.78049
# [301]	validation_0-merror:0.00000	validation_0-mlogloss:0.01091	validation_1-merror:0.21787	validation_1-mlogloss:0.78055
# [302]	validation_0-merror:0.00000	validation_0-mlogloss:0.01084	validation_1-merror:0.21805	validation_1-mlogloss:0.78154
# [303]	validation_0-merror:0.00000	validation_0-mlogloss:0.01073	validation_1-merror:0.21814	validation_1-mlogloss:0.78202
# [304]	validation_0-merror:0.00000	validation_0-mlogloss:0.01062	validation_1-merror:0.21778	validation_1-mlogloss:0.78189
# [305]	validation_0-merror:0.00000	validation_0-mlogloss:0.01052	validation_1-merror:0.21787	validation_1-mlogloss:0.78254
# [306]	validation_0-merror:0.00000	validation_0-mlogloss:0.01043	validation_1-merror:0.21787	validation_1-mlogloss:0.78220
# [307]	validation_0-merror:0.00000	validation_0-mlogloss:0.01036	validation_1-merror:0.21805	validation_1-mlogloss:0.78480
# [308]	validation_0-merror:0.00000	validation_0-mlogloss:0.01027	validation_1-merror:0.21760	validation_1-mlogloss:0.78482
# [309]	validation_0-merror:0.00000	validation_0-mlogloss:0.01021	validation_1-merror:0.21751	validation_1-mlogloss:0.78567
# [310]	validation_0-merror:0.00000	validation_0-mlogloss:0.01012	validation_1-merror:0.21769	validation_1-mlogloss:0.78570
# [311]	validation_0-merror:0.00000	validation_0-mlogloss:0.01006	validation_1-merror:0.21796	validation_1-mlogloss:0.78607
# [312]	validation_0-merror:0.00000	validation_0-mlogloss:0.01001	validation_1-merror:0.21751	validation_1-mlogloss:0.78570
# [313]	validation_0-merror:0.00000	validation_0-mlogloss:0.00991	validation_1-merror:0.21706	validation_1-mlogloss:0.78647
# [483]	validation_0-merror:0.00000	validation_0-mlogloss:0.00390	validation_1-merror:0.21742	validation_1-mlogloss:0.86858
# [484]	validation_0-merror:0.00000	validation_0-mlogloss:0.00388	validation_1-merror:0.21697	validation_1-mlogloss:0.86848
# [485]	validation_0-merror:0.00000	validation_0-mlogloss:0.00386	validation_1-merror:0.21769	validation_1-mlogloss:0.86901
# [486]	validation_0-merror:0.00000	validation_0-mlogloss:0.00385	validation_1-merror:0.21751	validation_1-mlogloss:0.86926
# [487]	validation_0-merror:0.00000	validation_0-mlogloss:0.00383	validation_1-merror:0.21760	validation_1-mlogloss:0.86983
# [488]	validation_0-merror:0.00000	validation_0-mlogloss:0.00381	validation_1-merror:0.21769	validation_1-mlogloss:0.86997
# [489]	validation_0-merror:0.00000	validation_0-mlogloss:0.00380	validation_1-merror:0.21760	validation_1-mlogloss:0.87033
# [490]	validation_0-merror:0.00000	validation_0-mlogloss:0.00378	validation_1-merror:0.21805	validation_1-mlogloss:0.87158
# [491]	validation_0-merror:0.00000	validation_0-mlogloss:0.00377	validation_1-merror:0.21823	validation_1-mlogloss:0.87304
# [492]	validation_0-merror:0.00000	validation_0-mlogloss:0.00375	validation_1-merror:0.21787	validation_1-mlogloss:0.87337
# [493]	validation_0-merror:0.00000	validation_0-mlogloss:0.00373	validation_1-merror:0.21823	validation_1-mlogloss:0.87509
# [494]	validation_0-merror:0.00000	validation_0-mlogloss:0.00372	validation_1-merror:0.21814	validation_1-mlogloss:0.87546
# [495]	validation_0-merror:0.00000	validation_0-mlogloss:0.00371	validation_1-merror:0.21823	validation_1-mlogloss:0.87550
# [496]	validation_0-merror:0.00000	validation_0-mlogloss:0.00369	validation_1-merror:0.21814	validation_1-mlogloss:0.87592
# [497]	validation_0-merror:0.00000	validation_0-mlogloss:0.00368	validation_1-merror:0.21760	validation_1-mlogloss:0.87612
# [498]	validation_0-merror:0.00000	validation_0-mlogloss:0.00366	validation_1-merror:0.21742	validation_1-mlogloss:0.87567
# [499]	validation_0-merror:0.00000	validation_0-mlogloss:0.00364	validation_1-merror:0.21706	validation_1-mlogloss:0.87635

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np

# Initialize the XGBClassifier
model = XGBClassifier(n_estimators=100, n_jobs=-1, random_state=42, use_label_encoder=False, eval_metric='logloss')

# Generate learning curve data (using 5-fold cross-validation)
train_sizes, train_scores, test_scores = learning_curve(
    estimator=model,
    X=x_train,
    y=y_train,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    train_sizes=np.linspace(0.1, 1.0, 10)
)

# Compute mean scores across folds
train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)

# Plot the learning curve
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_scores_mean, label='Training Accuracy', marker='o')
plt.plot(train_sizes, test_scores_mean, label='Cross-validation Accuracy', marker='o')
plt.xlabel('Number of Training Examples')
plt.ylabel('Accuracy')
plt.title('Learning Curve for XGBoost')
plt.legend()
plt.grid(True)
plt.show()
